# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
violations = pd.read_csv('data.csv')

# %%
violations.head()
# Out:
#         CITY  TOTAL VIOLATIONS neighborhood  population    white
# 0  ALMAHNBRA                 5     Alhambra     84866.0   7722.0
# 1   ALTADENA                 1     Altadena     44650.0  17385.0
# 2    ARCADIA                 7      Arcadia     57302.0  13644.0
# 3    ARTESIA                 2      Artesia     16789.0   3357.0
# 4      AZUSA                 4        Azusa     47322.0   9413.0

# %%
mapla = pd.read_csv('mapla_race_LA_community_2016.csv')

# %%
mapla.head()
# Out:
#     community_name               community_type community_parent  \
# 0            Acton  Unincorporated neighborhood            Acton
# 1  Adams-Normandie    Incorporated neighborhood  Adams-Normandie
# 2     Agoura Hills                         City     Agoura Hills
# 3       Agua Dulce  Unincorporated neighborhood       Agua Dulce
# 4         Alhambra                         City         Alhambra
#
#    tot_pop_univ         white        black           asn          hisp  \
# 0   7226.242164   5358.564287   157.866196    108.394164   1296.195217
# 1  17173.318153   1094.246151  3737.009035   1345.035721  10784.346299
# 2  20631.057701  15698.539269   326.922526   1334.925552   2649.295683
# 3   3500.769739   2550.826748    11.423372     82.937442    621.517179
# 4  84866.000000   7722.000000  1494.000000  42902.000000  31289.000000
#
#            oth  pct_tot_pop_univ  pct_white  pct_black   pct_asn  pct_hisp  \
# ...
